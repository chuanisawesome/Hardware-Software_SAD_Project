# %%
import numpy as np
import pandas as pd
import csv

# %%
f = open('sensor data/heartrate.csv', 'r')
df = pd.read_csv(f)
# show first 5 rows
df["value"]
# Out:
# 0      77.0
# 1      77.0
# 2      77.0
# 3      74.0
# 4      73.0
#        ...
# 319    74.0
# 320    98.0
# 321    90.0
# 322    86.0
# 323    69.0
# Name: value, Length: 324, dtype: float64

# %%
# plot the data
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(df["value"])
fig.set_size_inches(15, 8)
